# %% [markdown]
# # Employees Salaries Exploratory Data Analysis (EDA)
#
# This project analyzes employee salary data to identify salary trends, job title patterns, and compensation insights using Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('Display.max_columns',None)

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ## Display top 10 rows of the Dataset

# %%
# Task 1: Access the top 10 rows of the Dataset
# To access the top 10 Rows of dataset we use head() function
# other alternatives --> df.loc[],df.iloc[] and df[rowstart:rowend:step]
print('Top 10 Rows of the Dataset')
print('----------------------------')
df.head(10)
# Out:
# Top 10 Rows of the Dataset
# ----------------------------
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# ## Check last 10 Rows of dataset

# %%
# Task 2: Access last 10 rows in the dataset
# To access last 10 rows we use tail() function
# other ways df.loc,df.iloc and df[len(df)-10]
print('Last 10 rows of the dataset')
print('--------------------------------')
df[len(df)-10:]
# Out:
# Last 10 rows of the dataset
# --------------------------------
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# ...

# %% [markdown]
# ## Find number of rows and columns in the dataset

# %%
# Task 3: Find the number of rows and columns in the dataset
# To find number of rows and columns we use shape attribute
print('Total Number of rows and columns in the dataset')
print('-------------------------------------------------')
for rows,columns in [df.shape]:
    print('Number of rows =',rows)
    print('Number of columns =',columns)
print('-------------------------------------------------')
# Out:
# Total Number of rows and columns in the dataset
# -------------------------------------------------
# Number of rows = 148654
# Number of columns = 13
# -------------------------------------------------

# %% [markdown]
# ## Get the information about dataset like total number of rows, total number of columns, datatypes of each columns and memory requirement

# %%
# Task 4: Find the number of rows/columns and data type of each column along with memory requirement
# To access the memory requirement,number rows/columns, non-null values we use a function info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# ## Check null values in the Dataset

# %%
# Task 5: Display the number of null values in each column
# To get the number of null values in each column we can use isna() and isnull() functions
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# ## Drop ID,Notes,Agency and status columns

# %%
# Task 6: Drop ID,Notes,Agency and status columns
# To remove the columns or rows we use drop() function 
# Hare axis=1 refers to the columns(axis=0 is for rows)
df = df.drop(['Id','Notes','Agency','Status'],axis=1)
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# ## Get overall statistics in the dataframe

# %%
# Task 7: Get overall statistics in the dataframe
# To get the overall description of the data we use describe() function
df.describe(include='all')
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        148654            148654  148045.000000  148650.000000
# unique       110811              2159            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             13              7036            NaN            NaN
# mean            NaN               NaN   66325.448840    5066.059886
# std             NaN               NaN   42764.635495   11454.380559
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   33588.200000       0.000000
# 50%             NaN               NaN   65007.450000       0.000000
# 75%             NaN               NaN   94691.050000    4658.175000
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay       Benefits       TotalPay  TotalPayBenefits  \
# count   148650.000000  112491.000000  148654.000000     148654.000000
# ...

# %% [markdown]
# ## Find the Top 5 Most Common Employee Names

# %%
# Task 8: Find the occurences of first 5 employee names
# To obtain the number of repeat values in employeename we use head() and value_counts() functions
df['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# John Chan        9
# Name: count, dtype: int64

# %% [markdown]
# ## Find the number of unique job titles

# %%
# Task 9: Find the number of unique job tittles
# To know the number of unique value we use nunique() function 
# nunique() will give number of unique values
print('Number of unique job tittles =',df['JobTitle'].nunique())
# Out:
# Number of unique job tittles = 2159

# %% [markdown]
# ## Find the Total Number of Job Titles Containing "Captain"

# %%
# Task 10: Find total number of job tittles contain captain
# To obtain number of job titles containing captain 
# We should obtain the jobtitles with captain gives the series object
# lenth of the series will give the number of jobtitle with captain
captain = len(df[df['JobTitle'].str.contains('Captain')]['JobTitle'])
print('Number of titles containing Captain =',captain)
# Out:
# Number of titles containing Captain = 411

# %% [markdown]
# ## Display all the employee names from fire department

# %%
# Task 11: Display all the employee names from fire department
# To obtain EmoployeeName from Firedepartment 
# Obtain the rows with of jobtitle with fire department then access the employeenames
print('Employees belongs to Fire Department')
print('----------------------------------------------------------')
df[df['JobTitle'].str.contains('FIRE DEPARTMENT')]['EmployeeName']
# Out:
# Employees belongs to Fire Department
# ----------------------------------------------------------
# 4           PATRICK GARDNER
# 6                 ALSON LEE
# 8            MICHAEL MORRIS
# 9        JOANNE HAYES-WHITE
# 10            ARTHUR KENNEY
#                 ...
# 4955              AUDRY LEE
# 5498          VINCENT PEREZ
# 8436          JENSEN RHODES
# 16285       AARON STEVENSON
# 32623          JAMES BARDEN
# Name: EmployeeName, Length: 222, dtype: object

# %% [markdown]
# ## Find the Minimum, Maximum, and Average Base Pay

# %%
# Task 12: Find the Minimum, Maximum, and Average Base Pay
# To know the min, mean and max values of BasePay
# We use agg() function 
print('Minimum,Maximum and Average values of BasePay')
print('--------------------------------------------------')
df['BasePay'].agg(['min','mean','max'])
# Out:
# Minimum,Maximum and Average values of BasePay
# --------------------------------------------------
# min       -166.01000
# mean     66325.44884
# max     319275.01000
# Name: BasePay, dtype: float64

# %% [markdown]
# ##  Data Cleaning

# %% [markdown]
# ## Replace 'not provided' in employee name to NaN

# %%
# Task 13: Replace 'not provided' in employee name to NaN
# To replace 'not provided' with NaN we use replace() function
# To access those values use isna() or isnull()
df['EmployeeName'] = df['EmployeeName'].replace('Not provided',np.nan)
df[df['EmployeeName'].isna()]
# Out:
#        EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 148646          NaN  Not provided      NaN          NaN       NaN       NaN
# 148650          NaN  Not provided      NaN          NaN       NaN       NaN
# 148651          NaN  Not provided      NaN          NaN       NaN       NaN
# 148652          NaN  Not provided      NaN          NaN       NaN       NaN
#
#         TotalPay  TotalPayBenefits  Year
# 148646       0.0               0.0  2014
# 148650       0.0               0.0  2014
# 148651       0.0               0.0  2014
# 148652       0.0               0.0  2014

# %% [markdown]
# ## Drop rows with 5 missing values

# %%
# Task 14: Drop the rows having 5 missing values
# To drop the rows with 5 missing values first find the rows with 5 missing values
# Use drop() function to remove rows
ind = df[df.isnull().sum(axis=1) == 5].index
df = df.drop(ind)
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# ## Find the job title of Albert Pardini

# %%
# Task 15: Find the job tittle of Albert Pardini
# To know the job title of Albert Pardini using EmployeeName we can access the jobtitle column
# This gives series output then access the values in the series

print('Job title of Alber Pardini is',df[df['EmployeeName']=='Albert Pardini']['JobTitle'].values)
# Out:
# Job title of Alber Pardini is ['Captain 3']

# %% [markdown]
# ## Find how Much Did Albert Pardini Earn (Including Benefits)

# %%
# Task 16: Find how much Albert Pardini make(Include benefits)
# To find the income of Albert Pardinin including benefits we should access the total benefits column
# this gives a series object using 'values' attribute you can get the TotalPayBenefits
print('Total income of Albert Pardini including benefits =',df[df['EmployeeName']=='Albert Pardini']['TotalPayBenefits'].values)
# Out:
# Total income of Albert Pardini including benefits = [253995.29]

# %% [markdown]
# ## Display name of the person having highest base pay

# %%
# Task 17: Display name of the person having highest base pay
# To get the EmployeeName with highest BasePay we use max()
# Find the maximum of BasePay then access name of the Employee
print('Person with highest BasePay =',df[df['BasePay']==df['BasePay'].max()]['EmployeeName'].values)
# Out:
# Person with highest BasePay = ['Gregory P Suhr']

# %% [markdown]
# ## Average base pay of all employees per year

# %%
# Task 18: Average base pay of all employees per year
# To obtain the average BasePay per year we should use groupby() function for Year column
# Use mean() function to obtain
print('Average BasePay per year')
print('----------------------------')
df2 = df.groupby('Year')
df2['BasePay'].mean()
# Out:
# Average BasePay per year
# ----------------------------
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ## Average Base Pay by Job Title

# %%
# Task 19: Average base pay of employees per job title
# To obtain the average BasePay per year we should use groupby() function for jobtitle column
# Use mean() function to obtain
df3 = df.groupby('JobTitle')
df3['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2158, dtype: float64

# %% [markdown]
# ## Average Base Pay of Employees with the Job Title "Accountant"

# %%
# Task 20: Average base pay of employees having job title Accountant
# To obtain the BasePay of the employee with jobtitle Accountant
# Access the employees with jobtitle accountant then access their BasePay and use mean() function to obtain average
df[df['JobTitle'].str.contains('Accountant')]['BasePay'].mean()
# Out:
# np.float64(75336.18288798921)

# %% [markdown]
# ## Find top 5 most common jobs

# %%
# Task 21: Find top 5 most common jobs
# To obtain the top 5 most repeated job titles
# Use the value_counts() function and head() function for JobTitle 
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# ## Visualize a bar graph for Overtime Pay Analysis

# %%
# Task 22: Visualize a bar graph for overtime pay Analysis
# To visualize overtimepay analysis use groupby() function for jobtitle and access the average overtimepay
# Sort the values and use head() to access the top 10 values then plot the bar graph
top_overtime = (df.groupby('JobTitle')['OvertimePay']
                  .mean()
                  .sort_values(ascending=False)
                  .head(10))
plt.figure(figsize=(10,6))
top_overtime.plot(kind='bar')
plt.title('Overtime Pay Analysis')
plt.xlabel('Job Title')
plt.ylabel('Average Overtime Pay')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Visualize the salary distribution Histogram of employees

# %%
# Task 23: Visualize the total pay of  employees
# To visualize the total pay of employees we access the totalpay
# Using plt.hist() we can visualize the graph
plt.figure(figsize=(8,5))
plt.hist(df['TotalPay'], bins=30, edgecolor='black')
plt.xlabel('Total Pay')
plt.ylabel('Number of Employees')
plt.title('Salary Distribution of Employees')
plt.show()

# %% [markdown]
# ## Visualize the Top 5 Job Titles with the Highest Average Base Pay

# %%
# Task 24: Visualize the top 5 job titles with highest average basepay
# To visualize top 5 job titles with highest average basepay access the unique job titles then obtain average basepay 
# Sort average baspay in descending order and access the top 5 values using plt.pie() obtain the pie chart 
average_basepay = df.groupby('JobTitle')['BasePay'].mean().sort_values(ascending=False).head().values
job_title = df.groupby('JobTitle')['BasePay'].mean().sort_values(ascending=False).head().index
plt.pie(average_basepay,labels=job_title,autopct='%0.2f%%')
plt.title('Top 5 Job Titles with Highest Average Base Pay')
plt.show()

# %% [markdown]
# ## Plot a graph for top 10 Highest Paying Job Titles

# %%
# Task 25: Visualize a bar graph for average TotalPaybenefits of top 10 highest paying jobs
# To visualize this we use groupby() of jobtitle and then access the average totalpaybenefits sort them
# Using head() access the top 10 and obtain the graph
top_jobs = df.groupby('JobTitle')['TotalPayBenefits'].mean().sort_values(ascending=False).head(10).index
average_paybenefits = df.groupby('JobTitle')['TotalPayBenefits'].mean().sort_values(ascending=False).head(10).values
plt.figure(figsize=(18,5))
plt.bar(top_jobs,average_paybenefits)
plt.title('Top 10 Highest Paying Job Titles')
plt.xticks(rotation=90)
plt.xlabel('Job titles',size=15)
plt.ylabel('Average Total Pay Benefits')
plt.show()

# %% [markdown]
# ## Visualize the average of totalpaybenefits each year

# %%
# Task 26: Visualize the average of totalpaybenefits each year
# To visualize the average of totalpaybenefits each year use groupby() for year obtain average of totalpaybenefits
# Using astype() convert the years to string then plot the bar graph using plt.bar()
eachyear_avg = df.groupby('Year')['TotalPayBenefits'].mean().values
year = df.groupby('Year')['TotalPayBenefits'].mean().index.astype('str')
plt.bar(year,eachyear_avg)
plt.xlabel('Year')
plt.ylabel('Average of totalpaybenefits')
plt.title('Average Total Pay Benefits by Year')
plt.show()

# %% [markdown]
# ## Conclusion
#
# - Leadership positions had the highest average base pay.
# - Operational roles earned higher overtime compensation.
# - Most employees received moderate salaries.
# - Employee compensation varied across different years.
# - Data analysis helped uncover useful insights from the salary dataset.
